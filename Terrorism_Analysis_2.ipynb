# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('terrorismData.csv')

# %%
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
#Part 1

# %%
#The most dangerous city in Jammu&Kashmir and the terrorisyt group most active there
#print count of number of attacks
#ignore the unknown terrorist groups

# %%
df2= df.loc[df['State']=='Jammu and Kashmir']

# %%
df2
# Out:
#         Year  Month  Day Country              State      Region  \
# 21744   1984      4   17   India  Jammu and Kashmir  South Asia
# 22108   1984      5   20   India  Jammu and Kashmir  South Asia
# 29677   1986     12   11   India  Jammu and Kashmir  South Asia
# 33202   1988      1   21   India  Jammu and Kashmir  South Asia
# 33372   1988      2    7   India  Jammu and Kashmir  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181222  2017     12   11   India  Jammu and Kashmir  South Asia
# 181396  2017     12   18   India  Jammu and Kashmir  South Asia
# 181414  2017     12   19   India  Jammu and Kashmir  South Asia
# 181476  2017     12   22   India  Jammu and Kashmir  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
#
#                       City   Latitude  Longitude         AttackType  Killed  \
# 21744                Bhela  33.315527  74.622476      Assassination     2.0
# ...

# %%
df2['City'].value_counts()
# Out:
# City
# Srinagar    657
# Sopore      102
# Unknown      86
# Anantnag     76
# Jammu        57
#            ...
# Barburgh      1
# Zewan         1
# Panzer        1
# Barbugh       1
# Thathar       1
# Name: count, Length: 633, dtype: int64

# %%
df3= df2.loc[df2['City']=='Srinagar']

# %%
df3
# Out:
#         Year  Month  Day Country              State      Region      City  \
# 35266   1988      7   31   India  Jammu and Kashmir  South Asia  Srinagar
# 35267   1988      7   31   India  Jammu and Kashmir  South Asia  Srinagar
# 36073   1988     10   27   India  Jammu and Kashmir  South Asia  Srinagar
# 36074   1988     10   27   India  Jammu and Kashmir  South Asia  Srinagar
# 36078   1988     10   27   India  Jammu and Kashmir  South Asia  Srinagar
# ...      ...    ...  ...     ...                ...         ...       ...
# 179570  2017     10   10   India  Jammu and Kashmir  South Asia  Srinagar
# 179684  2017     10   14   India  Jammu and Kashmir  South Asia  Srinagar
# 180599  2017     11   19   India  Jammu and Kashmir  South Asia  Srinagar
# 180822  2017     11   27   India  Jammu and Kashmir  South Asia  Srinagar
# 181476  2017     12   22   India  Jammu and Kashmir  South Asia  Srinagar
#
#         Latitude  Longitude         AttackType  Killed  Wounded  \
# ...

# %%
df3.loc[df3['Group']=='Unknown']=np.nan

# %%
df3['Group'].value_counts()
# Out:
# Group
# Muslim Separatists                    55
# Jammu and Kashmir Liberation Front    45
# Kashmiri extremists                   37
# Muslim Militants                      35
# Hizbul Mujahideen (HM)                31
# Separatists                           21
# Lashkar-e-Taiba (LeT)                 21
# Jaish-e-Mohammad (JeM)                12
# Al-Mansoorian                         12
# Sikh Extremists                        9
# Al-Umar Mujahideen                     8
# Jamiat ul-Mujahedin (JuM)              6
# Al-Madina                              4
# Lashkar-e-Islam (India)                4
# Tehrik al-Mojahedin                    3
# Kashmiri Hezbollah                     3
# Al-Arifeen                             3
# Muslim extremists                      3
# Islamic Front                          3
# Ikhwan-ul-Muslimeen                    2
# Muslim Janbaz Force                    2
# Muslim Brotherhood                     2
# Allah's Tigers                         2
# ...

# %%
df2['City'].value_counts().max
# Out:
# <bound method Series.max of City
# Srinagar    657
# Sopore      102
# Unknown      86
# Anantnag     76
# Jammu        57
#            ...
# Barburgh      1
# Zewan         1
# Panzer        1
# Barbugh       1
# Thathar       1
# Name: count, Length: 633, dtype: int64>

# %%
#since we have found all the required data , now its time to give the ouput in desired format

# %%
#Format
#City No.of Attacks Group involved

# %%
#Part 2

# %%
#Find out the country with the highest number of terror attacks and in which year the most number of attacks happened

# %%
df['Country'].value_counts().max
# Out:
# <bound method Series.max of Country
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# Antigua and Barbuda        1
# North Korea                1
# Wallis and Futuna          1
# St. Lucia                  1
# International              1
# Name: count, Length: 205, dtype: int64>

# %%
df_iraq=df.loc[df['Country']=='Iraq']

# %%
df_iraq
# Out:
#         Year  Month  Day Country    State                      Region  \
# 2854    1975      3    1    Iraq  Nineveh  Middle East & North Africa
# 4385    1976     12   15    Iraq  Baghdad  Middle East & North Africa
# 4393    1976     12   18    Iraq  Unknown  Middle East & North Africa
# 4402    1976     12   24    Iraq  Baghdad  Middle East & North Africa
# 8688    1979      6   15    Iraq    Basra  Middle East & North Africa
# ...      ...    ...  ...     ...      ...                         ...
# 181669  2017     12   30    Iraq   Kirkuk  Middle East & North Africa
# 181670  2017     12   31    Iraq   Diyala  Middle East & North Africa
# 181671  2017     12   31    Iraq  Saladin  Middle East & North Africa
# 181674  2017     12   31    Iraq  Nineveh  Middle East & North Africa
# 181679  2017     12   31    Iraq   Diyala  Middle East & North Africa
#
#                 City   Latitude  Longitude                   AttackType  \
# ...

# %%
df_iraq['Year'].value_counts().max
# Out:
# <bound method Series.max of Year
# 2014    3933
# 2016    3360
# 2013    2852
# 2015    2751
# 2017    2466
# 2012    1437
# 2011    1308
# 2010    1179
# 2009    1137
# 2008    1106
# 2007    1047
# 2006     838
# 2005     617
# 2004     323
# 2003     102
# 1992      35
# 1997      21
# 1994      18
# 1995      17
# 1999      12
# 1996      12
# 2000      10
# 1998       7
# 1980       6
# 2002       6
# 1982       5
# 1988       4
# 1989       4
# 1981       3
# 1991       3
# 2001       3
# 1976       3
# 1983       3
# 1987       3
# 1979       2
# 1984       2
# 1975       1
# Name: count, dtype: int64>

# %%
#we have found the desired data but it is not in the optimum output format

# %%
#Part 3

# %%
#most deadlist attack in the history of human kind, print count of killed people
#output : num of people killed country terrorist group

# %%
ser = df.loc[df['Killed']==df['Killed'].max()]

# %%
ser
# Out:
#         Year  Month  Day Country    State                      Region    City  \
# 133518  2014      6   12    Iraq  Saladin  Middle East & North Africa  Tikrit
#
#          Latitude  Longitude                   AttackType  Killed  Wounded  \
# 133518  34.621521  43.668377  Hostage Taking (Kidnapping)  1570.0      NaN
#
#           Target                                            Summary  \
# 133518  Soldiers  06/12/2014: Assailants abducted approximately ...
#
#                                               Group Target_type Weapon_type
# 133518  Islamic State of Iraq and the Levant (ISIL)    Military    Firearms

# %%
#Part 4

# %%
#Find the number of attacks in india from 2014 till date present in the data
#total attacks and most active terrorist group

# %%
df31= df.loc[df['Country']=='India']

# %%
df31
# Out:
#         Year  Month  Day Country              State      Region  \
# 1186    1972      2   22   India              Delhi  South Asia
# 2764    1975      1    2   India              Bihar  South Asia
# 3857    1976      5   26   India              Delhi  South Asia
# 5327    1977      9   28   India        Maharashtra  South Asia
# 7337    1979      1   13   India              Assam  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 1186        New Delhi  28.585836  77.153336                       Hijacking
# ...

# %%
df31.loc[df31['Year']>=2014]
# Out:
#         Year  Month  Day Country              State      Region  \
# 125343  2014      1    1   India            Manipur  South Asia
# 125344  2014      1    1   India            Manipur  South Asia
# 125366  2014      1    1   India            Haryana  South Asia
# 125373  2014      1    1   India             Odisha  South Asia
# 125374  2014      1    1   India       Chhattisgarh  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 125343      Singjamei  24.798346  93.940430               Bombing/Explosion
# ...

# %%
df31.loc[df31['Group']=='Unknown']=np.nan

# %%
df31['Group'].value_counts(dropna= True).max
# Out:
# <bound method Series.max of Group
# Communist Party of India - Maoist (CPI-Maoist)    1877
# Maoists                                           1396
# Sikh Extremists                                    710
# United Liberation Front of Assam (ULFA)            357
# Hizbul Mujahideen (HM)                             199
#                                                   ...
# Rajput extremists                                    1
# Palestinians                                         1
# Liberal Democratic Council for Missing Land          1
# Indigenous People's Front of Tripura (IPFT)          1
# Ansar Ghazwat-ul-Hind                                1
# Name: count, Length: 300, dtype: int64>

# %%
#Part 5

# %%
#Find the frequency of the casuality in the red corridor states and in jk 
#The red corridor states includes jharkhand, odisha, andhra pradesh, and Chattisgarh.
#here casuality= killed+wounded
#dont fill the nan value present in killed and wounded feature
#freq= total casuality/total number of year

# %%
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
#lets do it for JK first

# %%
df51 = df.loc[df['State']=='Jammu and Kashmir']

# %% [markdown]
# ##### df51

# %%
ser5 = pd.Series(df51['Killed']+df51['Wounded'])

# %%
ser5
# Out:
# 21744      2.0
# 22108      1.0
# 29677      6.0
# 33202      2.0
# 33372      9.0
#           ...
# 181222     3.0
# 181396     0.0
# 181414     0.0
# 181476     0.0
# 181672    11.0
# Length: 2454, dtype: float64

# %%
z=pd.Series(df51['Killed']+df51['Wounded']).max()

# %%
z
# Out:
# np.float64(129.0)

# %%
df51.head(1)
# Out:
#        Year  Month  Day Country              State      Region   City  \
# 21744  1984      4   17   India  Jammu and Kashmir  South Asia  Bhela
#
#         Latitude  Longitude     AttackType  Killed  Wounded  \
# 21744  33.315527  74.622476  Assassination     2.0      0.0
#
#                                                Target Summary  \
# 21744  Gurbachan Singh Sandhar (Sikh lawyer) and wife     NaN
#
#                  Group                  Target_type Weapon_type
# 21744  Sikh Extremists  Private Citizens & Property     Unknown

# %%
df51.tail(1)
# Out:
#         Year  Month  Day Country              State      Region       City  \
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia  Lethapora
#
#          Latitude  Longitude     AttackType  Killed  Wounded Target  \
# 181672  33.966527  74.964225  Armed Assault     8.0      3.0   Camp
#
#                                                   Summary  \
# 181672  12/31/2017: Assailants armed with grenades and...
#
#                          Group Target_type Weapon_type
# 181672  Jaish-e-Mohammad (JeM)      Police  Explosives

# %%
df51.head(1)['Year']
# Out:
# 21744    1984
# Name: Year, dtype: int64

# %%
df51.tail(1)['Year']
# Out:
# 181672    2017
# Name: Year, dtype: int64

# %%
df51_killed= (df51['Killed'].dropna()).sum()

# %%
df51_wounded= (df51['Wounded'].dropna()).sum()

# %%
total_cas_jk= df51_killed+df51_wounded

# %%
total_cas_jk
# Out:
# np.float64(12648.0)

# %%
year = len(set(df51['Year']))

# %%
year
# Out:
# 31

# %%
freq = int(total_cas_jk/year)

# %%
freq #For Jk it is calculated
# Out:
# 408

# %%
#Red corridoar

# %%
df52 = df.loc[(df['State']=='Jharkhand')| (df['State']=='Odisha')| (df['State']=='Andhra Pradesh')| (df['State']=='Chattisgarh')]

# %%
df52
# Out:
#         Year  Month  Day Country           State      Region  \
# 9053    1979      8    8   India  Andhra Pradesh  South Asia
# 9148    1979      8   26   India       Jharkhand  South Asia
# 9166    1979      8   29   India       Jharkhand  South Asia
# 27651   1986      3   26   India  Andhra Pradesh  South Asia
# 33671   1988      3    3   India  Andhra Pradesh  South Asia
# ...      ...    ...  ...     ...             ...         ...
# 181439  2017     12   20   India       Jharkhand  South Asia
# 181471  2017     12   22   India  Andhra Pradesh  South Asia
# 181472  2017     12   22   India  Andhra Pradesh  South Asia
# 181615  2017     12   28   India       Jharkhand  South Asia
# 181661  2017     12   28   India  Andhra Pradesh  South Asia
#
#                       City   Latitude  Longitude  \
# 9053                Amapur  16.435329  77.831725
# 9148            Jamshedpur  22.804567  86.202875
# 9166            Jamshedpur  22.804567  86.202875
# ...

# %%
total_killed_rc = df52['Killed'].sum()

# %%
total_wounded_rc =df52['Wounded'].sum()

# %%
total_cas_rc = total_killed_rc+total_wounded_rc

# %%
year_rc = len(set(df52['Year']))

# %%
freq_rc= int(total_cas_rc/year_rc)

# %%
print(freq, freq_rc)
# Out:
# 408 100
